# %%
import pandas as pd
import numpy as np
import gzip
import json

# %% [markdown]
# # Cleaning Brands data and converting to csv

# %%
brands = pd.read_json(
        'brands.json.gz',
        lines=True,
        compression='gzip'
    )

# %%
brands.head()
# Out:
#                                     _id       barcode        category  \
# 0  {'$oid': '601ac115be37ce2ead437551'}  511111019862          Baking
# 1  {'$oid': '601c5460be37ce2ead43755f'}  511111519928       Beverages
# 2  {'$oid': '601ac142be37ce2ead43755d'}  511111819905          Baking
# 3  {'$oid': '601ac142be37ce2ead43755a'}  511111519874          Baking
# 4  {'$oid': '601ac142be37ce2ead43755e'}  511111319917  Candy & Sweets
#
#        categoryCode                                                cpg  \
# 0            BAKING  {'$id': {'$oid': '601ac114be37ce2ead437550'}, ...
# 1         BEVERAGES  {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, ...
# 2            BAKING  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 3            BAKING  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 4  CANDY_AND_SWEETS  {'$id': {'$oid': '5332fa12e4b03c9a25efd1e7'}, ...
#
#                         name  topBrand                      brandCode
# ...

# %%
brands.dtypes
#type(brands['cpg'][1])
# Out:
# _id              object
# barcode           int64
# category         object
# categoryCode     object
# cpg              object
# name             object
# topBrand        float64
# brandCode        object
# dtype: object

# %%
brands['_id'] = brands['_id'].apply(pd.Series)

# %%
brands.head()
# Out:
#                         _id       barcode        category      categoryCode  \
# 0  601ac115be37ce2ead437551  511111019862          Baking            BAKING
# 1  601c5460be37ce2ead43755f  511111519928       Beverages         BEVERAGES
# 2  601ac142be37ce2ead43755d  511111819905          Baking            BAKING
# 3  601ac142be37ce2ead43755a  511111519874          Baking            BAKING
# 4  601ac142be37ce2ead43755e  511111319917  Candy & Sweets  CANDY_AND_SWEETS
#
#                                                  cpg  \
# 0  {'$id': {'$oid': '601ac114be37ce2ead437550'}, ...
# 1  {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, ...
# 2  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 3  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 4  {'$id': {'$oid': '5332fa12e4b03c9a25efd1e7'}, ...
#
#                         name  topBrand                      brandCode
# 0  test brand @1612366101024       0.0                            NaN
# ...

# %%
brands_normalised = pd.json_normalize(brands['cpg'])
brands_normalised = brands_normalised.add_prefix('cpg.')
brands_normalised
# Out:
#      cpg.$ref              cpg.$id.$oid
# 0        Cogs  601ac114be37ce2ead437550
# 1        Cogs  5332f5fbe4b03c9a25efd0ba
# 2        Cogs  601ac142be37ce2ead437559
# 3        Cogs  601ac142be37ce2ead437559
# 4        Cogs  5332fa12e4b03c9a25efd1e7
# ...       ...                       ...
# 1162     Cogs  5f77274dbe37ce6b592e90bf
# 1163     Cogs  53e10d6368abd3c7065097cc
# 1164     Cogs  5332fa12e4b03c9a25efd1e7
# 1165     Cogs  5332f5f6e4b03c9a25efd0b4
# 1166     Cogs  6026d757be37ce6369301467
#
# [1167 rows x 2 columns]

# %%
brands_v1 = pd.merge(brands, brands_normalised, left_index=True, right_index=True, how='outer')

# %%
brands_v1.shape
# Out:
# (1167, 10)

# %%
brands_v1.dtypes
# Out:
# _id              object
# barcode           int64
# category         object
# categoryCode     object
# cpg              object
# name             object
# topBrand        float64
# brandCode        object
# cpg.$ref         object
# cpg.$id.$oid     object
# dtype: object

# %%
brands_v1.head()
# Out:
#                         _id       barcode        category      categoryCode  \
# 0  601ac115be37ce2ead437551  511111019862          Baking            BAKING
# 1  601c5460be37ce2ead43755f  511111519928       Beverages         BEVERAGES
# 2  601ac142be37ce2ead43755d  511111819905          Baking            BAKING
# 3  601ac142be37ce2ead43755a  511111519874          Baking            BAKING
# 4  601ac142be37ce2ead43755e  511111319917  Candy & Sweets  CANDY_AND_SWEETS
#
#                                                  cpg  \
# 0  {'$id': {'$oid': '601ac114be37ce2ead437550'}, ...
# 1  {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, ...
# 2  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 3  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 4  {'$id': {'$oid': '5332fa12e4b03c9a25efd1e7'}, ...
#
#                         name  topBrand                      brandCode  \
# 0  test brand @1612366101024       0.0                            NaN
# ...

# %%
brands_v1.to_csv('brands.csv')

# %% [markdown]
# # Cleaning Users data and converting to csv

# %%
users = pd.read_json(
        'users.json.gz',
        lines=True,
        compression='gzip'
    )
users.head()
# Out:
#                                     _id  active               createdDate  \
# 0  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 1  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 2  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
# 3  {'$oid': '5ff1e1eacfcf6c399c274ae6'}    True  {'$date': 1609687530554}
# 4  {'$oid': '5ff1e194b6a9d73a3a9f1052'}    True  {'$date': 1609687444800}
#
#                   lastLogin      role signUpSource state
# 0  {'$date': 1609687537858}  consumer        Email    WI
# 1  {'$date': 1609687537858}  consumer        Email    WI
# 2  {'$date': 1609687537858}  consumer        Email    WI
# 3  {'$date': 1609687530597}  consumer        Email    WI
# 4  {'$date': 1609687537858}  consumer        Email    WI

# %%
users['_id'] = users['_id'].apply(pd.Series)

# %%
users['createdDate'] = users['createdDate'].apply(pd.Series)

# %%
a = users['lastLogin'].apply(pd.Series)
a
users['lastLogin']= a['$date'].apply(pd.Series)

# %%
users['createdDate'] =(pd.to_datetime(users['createdDate'],unit='ms')) 
users['lastLogin'] =(pd.to_datetime(users['lastLogin'],unit='ms'))

# %%
users.head()
# Out:
#                         _id  active             createdDate  \
# 0  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 1  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 2  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 3  5ff1e1eacfcf6c399c274ae6    True 2021-01-03 15:25:30.554
# 4  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
#
#                       lastLogin      role signUpSource state
# 0 2021-01-03 15:25:37.857999872  consumer        Email    WI
# 1 2021-01-03 15:25:37.857999872  consumer        Email    WI
# 2 2021-01-03 15:25:37.857999872  consumer        Email    WI
# 3 2021-01-03 15:25:30.596999936  consumer        Email    WI
# 4 2021-01-03 15:25:37.857999872  consumer        Email    WI

# %%
users.to_csv('users.csv')

# %% [markdown]
# # Cleaning Receipts data and converting to csv

# %%
receipts = pd.read_json(
        'receipts.json.gz',
        lines=True,
        compression='gzip'
    )
receipts.head()
# Out:
#                                     _id  bonusPointsEarned  \
# 0  {'$oid': '5ff1e1eb0a720f0523000575'}              500.0
# 1  {'$oid': '5ff1e1bb0a720f052300056b'}              150.0
# 2  {'$oid': '5ff1e1f10a720f052300057a'}                5.0
# 3  {'$oid': '5ff1e1ee0a7214ada100056f'}                5.0
# 4  {'$oid': '5ff1e1d20a7214ada1000561'}                5.0
#
#                              bonusPointsEarnedReason  \
# 0  Receipt number 2 completed, bonus point schedu...
# 1  Receipt number 5 completed, bonus point schedu...
# 2                         All-receipts receipt bonus
# 3                         All-receipts receipt bonus
# 4                         All-receipts receipt bonus
#
#                  createDate               dateScanned  \
# 0  {'$date': 1609687531000}  {'$date': 1609687531000}
# 1  {'$date': 1609687483000}  {'$date': 1609687483000}
# 2  {'$date': 1609687537000}  {'$date': 1609687537000}
# 3  {'$date': 1609687534000}  {'$date': 1609687534000}
# ...

# %%
receipts.shape
# Out:
# (1119, 15)

# %%
receipts = receipts.explode('rewardsReceiptItemList')
receipts.reset_index(inplace=True)

# %%
import ast
receipts = receipts.fillna({'rewardsReceiptItemList':'{}'})
receipts['rewardsReceiptItemList'] = receipts['rewardsReceiptItemList'].apply(lambda x:str(x))
receipts['rewardsReceiptItemList'] = receipts['rewardsReceiptItemList'].apply(lambda x: ast.literal_eval(str(x)))

# %%
receipts_norm = pd.json_normalize(receipts['rewardsReceiptItemList'],errors='ignore',record_prefix='rewardsReceiptItemList').add_prefix('rewardsReceiptItemList.')

# %%
receipts_v1 = pd.merge(receipts, receipts_norm, left_index=True, right_index=True, how='outer')

# %%
#data check
#receipts_v1.iloc[2]
receipts_v1.head()
# Out:
#    index                                   _id  bonusPointsEarned  \
# 0      0  {'$oid': '5ff1e1eb0a720f0523000575'}              500.0
# 1      1  {'$oid': '5ff1e1bb0a720f052300056b'}              150.0
# 2      1  {'$oid': '5ff1e1bb0a720f052300056b'}              150.0
# 3      2  {'$oid': '5ff1e1f10a720f052300057a'}                5.0
# 4      3  {'$oid': '5ff1e1ee0a7214ada100056f'}                5.0
#
#                              bonusPointsEarnedReason  \
# 0  Receipt number 2 completed, bonus point schedu...
# 1  Receipt number 5 completed, bonus point schedu...
# 2  Receipt number 5 completed, bonus point schedu...
# 3                         All-receipts receipt bonus
# 4                         All-receipts receipt bonus
#
#                  createDate               dateScanned  \
# 0  {'$date': 1609687531000}  {'$date': 1609687531000}
# 1  {'$date': 1609687483000}  {'$date': 1609687483000}
# 2  {'$date': 1609687483000}  {'$date': 1609687483000}
# ...

# %%
receipts_v1['_id'] = receipts_v1['_id'].apply(pd.Series)

# %%
receipts_v1['createDate'] = receipts_v1['createDate'].apply(pd.Series)

# %%
receipts_v1['dateScanned'] = receipts_v1['dateScanned'].apply(pd.Series)

# %%
a = receipts_v1['finishedDate'].apply(pd.Series)
a
receipts_v1['finishedDate'] = a['$date'].apply(pd.Series)

# %%
receipts_v1['modifyDate'] = receipts_v1['modifyDate'].apply(pd.Series)

# %%
a = receipts_v1['pointsAwardedDate'].apply(pd.Series)
a
receipts_v1['pointsAwardedDate'] = a['$date'].apply(pd.Series)

# %%
a = receipts_v1['purchaseDate'].apply(pd.Series)
a
receipts_v1['purchaseDate'] = a['$date'].apply(pd.Series)

# %%
receipts_v1
# Out:
#       index                       _id  bonusPointsEarned  \
# 0         0  5ff1e1eb0a720f0523000575              500.0
# 1         1  5ff1e1bb0a720f052300056b              150.0
# 2         1  5ff1e1bb0a720f052300056b              150.0
# 3         2  5ff1e1f10a720f052300057a                5.0
# 4         3  5ff1e1ee0a7214ada100056f                5.0
# ...     ...                       ...                ...
# 7376   1115  603d0b710a720fde1000042a                NaN
# 7377   1116  603cf5290a720fde10000413                NaN
# 7378   1117  603ce7100a7217c72c000405               25.0
# 7379   1117  603ce7100a7217c72c000405               25.0
# 7380   1118  603c4fea0a7217c72c000389                NaN
#
#                                 bonusPointsEarnedReason     createDate  \
# 0     Receipt number 2 completed, bonus point schedu...  1609687531000
# 1     Receipt number 5 completed, bonus point schedu...  1609687483000
# ...

# %%
receipts_v1['createDate'] =(pd.to_datetime(receipts_v1['createDate'],unit='ms')) 
receipts_v1['dateScanned'] =(pd.to_datetime(receipts_v1['dateScanned'],unit='ms')) 
receipts_v1['finishedDate'] =(pd.to_datetime(receipts_v1['finishedDate'],unit='ms')) 
receipts_v1['modifyDate'] =(pd.to_datetime(receipts_v1['modifyDate'],unit='ms'))
receipts_v1['pointsAwardedDate'] =(pd.to_datetime(receipts_v1['pointsAwardedDate'],unit='ms')) 
receipts_v1['purchaseDate'] =(pd.to_datetime(receipts_v1['purchaseDate'],unit='ms')) 
receipts_v1
# Out:
#       index                       _id  bonusPointsEarned  \
# 0         0  5ff1e1eb0a720f0523000575              500.0
# 1         1  5ff1e1bb0a720f052300056b              150.0
# 2         1  5ff1e1bb0a720f052300056b              150.0
# 3         2  5ff1e1f10a720f052300057a                5.0
# 4         3  5ff1e1ee0a7214ada100056f                5.0
# ...     ...                       ...                ...
# 7376   1115  603d0b710a720fde1000042a                NaN
# 7377   1116  603cf5290a720fde10000413                NaN
# 7378   1117  603ce7100a7217c72c000405               25.0
# 7379   1117  603ce7100a7217c72c000405               25.0
# 7380   1118  603c4fea0a7217c72c000389                NaN
#
#                                 bonusPointsEarnedReason  \
# 0     Receipt number 2 completed, bonus point schedu...
# 1     Receipt number 5 completed, bonus point schedu...
# 2     Receipt number 5 completed, bonus point schedu...
# ...

# %%
receipts_v1.to_csv('receipts.csv')

# %% [markdown]
# # Identification of data issues

# %% [markdown]
# ### Check for Null or Missing values

# %%
brands_v1.isna().sum()
# Out:
# _id               0
# barcode           0
# category        155
# categoryCode    650
# cpg               0
# name              0
# topBrand        612
# brandCode       234
# cpg.$ref          0
# cpg.$id.$oid      0
# dtype: int64

# %%
brands_v1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1167 entries, 0 to 1166
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   _id           1167 non-null   object
#  1   barcode       1167 non-null   int64
#  2   category      1012 non-null   object
#  3   categoryCode  517 non-null    object
#  4   cpg           1167 non-null   object
#  5   name          1167 non-null   object
#  6   topBrand      555 non-null    float64
#  7   brandCode     933 non-null    object
#  8   cpg.$ref      1167 non-null   object
#  9   cpg.$id.$oid  1167 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 91.3+ KB

# %%
receipts_v1.isna().sum()
# Out:
# index                                                           0
# _id                                                             0
# bonusPointsEarned                                            1401
# bonusPointsEarnedReason                                      1401
# createDate                                                      0
# dateScanned                                                     0
# finishedDate                                                 1411
# modifyDate                                                      0
# pointsAwardedDate                                            1301
# pointsEarned                                                 1128
# purchaseDate                                                  458
# purchasedItemCount                                            484
# rewardsReceiptItemList                                          0
# rewardsReceiptStatus                                            0
# ...

# %%
receipts_v1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 50 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   index                                                      7381 non-null   int64
#  1   _id                                                        7381 non-null   object
#  2   bonusPointsEarned                                          5980 non-null   float64
#  3   bonusPointsEarnedReason                                    5980 non-null   object
#  4   createDate                                                 7381 non-null   datetime64[ns]
#  5   dateScanned                                                7381 non-null   datetime64[ns]
#  6   finishedDate                                               5970 non-null   datetime64[ns]
# ...

# %%
users.isna().sum()
# Out:
# _id              0
# active           0
# createdDate      0
# lastLogin       62
# role             0
# signUpSource    48
# state           56
# dtype: int64

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495 entries, 0 to 494
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   _id           495 non-null    object
#  1   active        495 non-null    bool
#  2   createdDate   495 non-null    datetime64[ns]
#  3   lastLogin     433 non-null    datetime64[ns]
#  4   role          495 non-null    object
#  5   signUpSource  447 non-null    object
#  6   state         439 non-null    object
# dtypes: bool(1), datetime64[ns](2), object(4)
# memory usage: 23.8+ KB

# %% [markdown]
# ### Check for duplicate values

# %%
print(users.shape)
deduped_users = users.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
print(deduped_users.shape)
# Out:
# (495, 7)
# (212, 7)

# %%
receipts_v1.drop('rewardsReceiptItemList', inplace=True, axis=1)
receipts_v1.head()
# Out:
#    index                       _id  bonusPointsEarned  \
# 0      0  5ff1e1eb0a720f0523000575              500.0
# 1      1  5ff1e1bb0a720f052300056b              150.0
# 2      1  5ff1e1bb0a720f052300056b              150.0
# 3      2  5ff1e1f10a720f052300057a                5.0
# 4      3  5ff1e1ee0a7214ada100056f                5.0
#
#                              bonusPointsEarnedReason          createDate  \
# 0  Receipt number 2 completed, bonus point schedu... 2021-01-03 15:25:31
# 1  Receipt number 5 completed, bonus point schedu... 2021-01-03 15:24:43
# 2  Receipt number 5 completed, bonus point schedu... 2021-01-03 15:24:43
# 3                         All-receipts receipt bonus 2021-01-03 15:25:37
# 4                         All-receipts receipt bonus 2021-01-03 15:25:34
#
#           dateScanned        finishedDate          modifyDate  \
# 0 2021-01-03 15:25:31 2021-01-03 15:25:31 2021-01-03 15:25:36
# 1 2021-01-03 15:24:43 2021-01-03 15:24:43 2021-01-03 15:24:48
# ...

# %%
print(receipts_v1.shape)
deduped_receipts = receipts_v1.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
print(deduped_receipts.shape)
# Out:
# (7381, 49)
# (7381, 49)

# %%
brands_v1.drop('cpg', inplace=True, axis=1)
brands_v1.head()
# Out:
#                         _id       barcode        category      categoryCode  \
# 0  601ac115be37ce2ead437551  511111019862          Baking            BAKING
# 1  601c5460be37ce2ead43755f  511111519928       Beverages         BEVERAGES
# 2  601ac142be37ce2ead43755d  511111819905          Baking            BAKING
# 3  601ac142be37ce2ead43755a  511111519874          Baking            BAKING
# 4  601ac142be37ce2ead43755e  511111319917  Candy & Sweets  CANDY_AND_SWEETS
#
#                         name  topBrand                      brandCode  \
# 0  test brand @1612366101024       0.0                            NaN
# 1                  Starbucks       0.0                      STARBUCKS
# 2  test brand @1612366146176       0.0  TEST BRANDCODE @1612366146176
# 3  test brand @1612366146051       0.0  TEST BRANDCODE @1612366146051
# 4  test brand @1612366146827       0.0  TEST BRANDCODE @1612366146827
#
#   cpg.$ref              cpg.$id.$oid
# 0     Cogs  601ac114be37ce2ead437550
# ...

# %%
print(brands_v1.shape)
deduped_brands = brands_v1.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
print(deduped_brands.shape)
# Out:
# (1167, 9)
# (1167, 9)

# %% [markdown]
# #### From above we can see that the 'users' table has 283 duplicate values. The other tables do not have duplicates.

# %% [markdown]
# ### Checking for time continuity in data

# %%
receipts_v1['month'] = pd.DatetimeIndex(receipts_v1['createDate']).month
receipts_v1['year'] = pd.DatetimeIndex(receipts_v1['createDate']).year
receipts_v1.head()
# Out:
#    index                       _id  bonusPointsEarned  \
# 0      0  5ff1e1eb0a720f0523000575              500.0
# 1      1  5ff1e1bb0a720f052300056b              150.0
# 2      1  5ff1e1bb0a720f052300056b              150.0
# 3      2  5ff1e1f10a720f052300057a                5.0
# 4      3  5ff1e1ee0a7214ada100056f                5.0
#
#                              bonusPointsEarnedReason          createDate  \
# 0  Receipt number 2 completed, bonus point schedu... 2021-01-03 15:25:31
# 1  Receipt number 5 completed, bonus point schedu... 2021-01-03 15:24:43
# 2  Receipt number 5 completed, bonus point schedu... 2021-01-03 15:24:43
# 3                         All-receipts receipt bonus 2021-01-03 15:25:37
# 4                         All-receipts receipt bonus 2021-01-03 15:25:34
#
#           dateScanned        finishedDate          modifyDate  \
# 0 2021-01-03 15:25:31 2021-01-03 15:25:31 2021-01-03 15:25:36
# 1 2021-01-03 15:24:43 2021-01-03 15:24:43 2021-01-03 15:24:48
# ...

# %%
AGG = receipts_v1.groupby(['year','month'])['_id'].count()
print(AGG)
# Out:
# year  month
# 2020  10         16
#       11         54
# 2021  1        6753
#       2         515
#       3          43
# Name: _id, dtype: int64

# %%
users['month'] = pd.DatetimeIndex(users['createdDate']).month
users['year'] = pd.DatetimeIndex(users['createdDate']).year
users.head()
# Out:
#                         _id  active             createdDate  \
# 0  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 1  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 2  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 3  5ff1e1eacfcf6c399c274ae6    True 2021-01-03 15:25:30.554
# 4  5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
#
#                       lastLogin      role signUpSource state  month  year
# 0 2021-01-03 15:25:37.857999872  consumer        Email    WI      1  2021
# 1 2021-01-03 15:25:37.857999872  consumer        Email    WI      1  2021
# 2 2021-01-03 15:25:37.857999872  consumer        Email    WI      1  2021
# 3 2021-01-03 15:25:30.596999936  consumer        Email    WI      1  2021
# 4 2021-01-03 15:25:37.857999872  consumer        Email    WI      1  2021

# %%
AGG = users.groupby(['year','month'])['_id'].count()
print(AGG)
# Out:
# year  month
# 2014  12        20
# 2015  4          1
# 2017  7          1
#       9         18
#       12         8
# 2020  1          1
#       7          1
#       11        24
#       12        20
# 2021  1        355
#       2         46
# Name: _id, dtype: int64
